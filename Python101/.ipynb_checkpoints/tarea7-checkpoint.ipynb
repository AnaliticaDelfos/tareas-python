# %%
#
#
# EJECUTAR ESTA CELDA
#
#

#####################################
#       Programación orientada a objetos
#####################################


import calificador
CORREO = "estudiante@analiticadelfos.com"

# %%
class Saludos:
    """
    Instrucciones:
        Los objetos creados a partir de esta clase
        deben contener una propiedad llamada saludo
        cuyo valor, al momento de creación, es la
        cadena de caracteres "Hola".

        Además debe contar con un método llamado
        mostrar_saludo que lo único que hace es 
        devolver la propiedad saludo.

    Nota:
        Dejamos marcados los métodos necesarios
        para esto, pasándole el parámetro self,
        sin embargo, más adelante dejarán de
        estar presentes y deberás escribirlos tu.
    """
    def __init__(self):
        ...

    def mostrar_saludo(self):
        ...

# %%
calificador.califica_clase_saludos(Saludos, CORREO, False)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 8 - ejercicio saludos <============
#
# ===============================================================================
#
#
#         ======================================================
#                     ||          Calificación: 100.0
#                     ||          Aciertos: 2
#                     ||          Errores: 0
#         ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: N/A.                     Valor esperado: Hola.                     Valor obtenido: Hola
#
# Valores de entrada: N/A.                     Valor esperado: Hola.                     Valor obtenido: Hola
#
# ======> No hubo errores :D <======
#
# ============> Enviando calificación <============
#
# ============> Calificación recibida <============

# %%
class Perro:
    """
    Instrucciones:
        Los objetos creados a partir de esta clase cuentan con una propiedad
        raza y una propiedad nombre, las cuales se inicializan como None.

        Además cuentan con un método llamado asignar_raza, el cual recibe
        la raza que tendrá el perro, modifica la propiedad raza con el valor
        recibido y devuelve la cadena "Raza asignada", 
        otro método llamado asignar nombre el que recibe el nombre que tendrá el perro,
        modifica la propiedad nombre y devuelve "Nombre asignado", por último
        cuentan con un método llamado ladrar, que lo único que hace
        es devolver la cadena "¡GUAU!".

    Nota:
        Dejamos marcados los métodos necesarios
        para esto, pasándole el parámetro self,
        sin embargo, más adelante dejarán de
        estar presentes y deberás escribirlos tu.
        
    """
    def __init__(self):
        """
        A esto nos referimos con inicializar como None
        """
        self.raza = None
        self.nombre = None
    
    def asignar_raza(self, raza):
        ...

    def asignar_nombre(self, nombre):
        ...

    def ladrar(self):
        ...

# %%
calificador.califica_clase_perro(Perro, CORREO, False)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 7 - ejercicio perro <============
#
# ===============================================================================
#
#
#         ======================================================
#                     ||          Calificación: 100.0
#                     ||          Aciertos: 5
#                     ||          Errores: 0
#         ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: N/A.                     Valor esperado: ¡GUAU!.                     Valor obtenido: ¡GUAU!
#
# Valores de entrada: Pastor alemán.                         Valor esperado: Raza asignada.                         Valor obtenido: Raza asignada
#
# Valores de entrada: Pepe.                         Valor esperado: Nombre asignado.                         Valor obtenido: Nombre asignado
#
# Valores de entrada: N/A.                     Valor esperado: Pastor alemán.                     Valor obtenido: Pastor alemán
#
# Valores de entrada: N/A.                     Valor esperado: Pepe.                     Valor obtenido: Pepe
#
# ======> No hubo errores :D <======
#
# ============> Enviando calificación <============
#
# ============> Calificación recibida <============

# %%
class CalculadoraBasica:
    """
    Instrucciones:
        Los objetos creados a partir de esta clase tienen una propiedad
        llamada marca que tiene como valor "Delfos".

        Además de contar con los siguientes métodos:
        Suma, resta, multiplicación y división, todos reciben
        2 números y devuelven el resultado de realizar
        la operación indicada por el nombre.

    """
    def __init__(self):
        self.marca = "Delfos"

    def suma(self, a, b):
        return a + b
    
    def resta(self, a, b):
        return a - b
    
    def multiplicacion(self, a, b):
        return a * b
    
    def division(self, a, b):
        if b == 0:
            return "No se puede dividir entre cero"
        else:
            return a / b

# %%
calificador.califica_clase_calculadora_basica(CalculadoraBasica, CORREO, False)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 7 - ejercicio calculadora_basica <============
#
# ===============================================================================
#
#
#         ======================================================
#                     ||          Calificación: 100.0
#                     ||          Aciertos: 10
#                     ||          Errores: 0
#         ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: N/A.                     Valor esperado: Delfos.                     Valor obtenido: Delfos
#
# Valores de entrada: [1, 2].                         Valor esperado: 3.                         Valor obtenido: 3
#
# Valores de entrada: [-1, -2].                         Valor esperado: -3.                         Valor obtenido: -3
#
# Valores de entrada: [-1, -2].                         Valor esperado: 1.                         Valor obtenido: 1
#
# Valores de entrada: [1, -2].                         Valor esperado: 3.                         Valor obtenido: 3
#
# Valores de entrada: [1, -2].                         Valor esperado: -2.                         Valor obtenido: -2
#
# Valores de entrada: [10, 20].                         Valor esperado: 200.                         Valor obtenido: 200
#
# Valores de entrada: [1, -2].                         Valor esperado: -0.5.                         Valor obtenido: -0.5
#
# Valores de entrada: [1, 2].                         Valor esperado: 0.5.                         Valor obtenido: 0.5
#
# Valores de entrada: [1, 0].                         Valor esperado: No se puede dividir entre cero.                         Valor obtenido: No se puede dividir entre cero
#
# ======> No hubo errores :D <======
#
# ============> Enviando calificación <============
#
# ============> Calificación recibida <============
