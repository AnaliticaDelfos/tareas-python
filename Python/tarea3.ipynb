# %%
#
#
# EJECUTAR ESTA CELDA
#
#

#####################################
#       Tarea 3
#####################################


import calificador
CORREO = "TU CORREO"

# %%
def penultimo_caracter(palabra):
    """
    Instrucciones:
        Esta función recibe una palabra como argumento
        llamado palabra
        y devuelve el penúltimo caracter de esa palabra

    Ejemplo:
        Si palabra = "Curso de Python"
        regresa 'o'

    Recuerda:
        Cuida la indentación.
        Recuerda que puedes usar índices negativos
    """

    # Escribe aquí tu código
    

    # Escribe aquí tu código
    
    return # Escribe aquí tu código

# %%
calificador.califica_penultimo_caracter(penultimo_caracter, CORREO, False)

# %%
def mostrar_numeros(a, b, c):
    """
    Instrucciones:
        Esta función recibe como parámetros
        tres números llamados
        a, b y c.

        La función debe regresar la cadena de caracteres
        a = <a>, b = <b> y c = <c>
        reemplazando lo que hay entre <> con el valor
        de la variable correspondiente

    Ejemplo:
        Si a = 2
        b = 3
        c = 4
        La función regresa 'a = 2, b = 3 y c = 4' (Ojo con los espacios)

    Recuerda:
        Para meter variables dentro de cadenas de caracteres
        puedes anteponer la letra f antes de las comillas
        y luego usar llaves {} para meter la variable:
        Si a = 1
        f"a = {a}" (nota que le estoy pasando la variable)
        devuelve 'a = 1'
        O puedes usar la función format()
        Si a = 1
        "a = {0}".format(a) (nota el uso de índices en este caso)
        devuelve 'a = 1'

    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código


    # Escribe aquí tu código
    
    return # Escribe aquí tu código

# %%
calificador.califica_mostrar_numeros(mostrar_numeros, CORREO, False)

# %%
def mostrar_caracteres(palabra1, palabra2, palabra3):
    """
    Instrucciones:
        Esta función recibe como parámetros
        tres palabras palabra1, palabra2, palabra3.

        La función obtiene el caracter en la penúltima
        posición de cada palabra y devuelve la cadena

        'C1 = < ... >, C2 = < ... >, C3 = < ... >'

        Donde se sustituyen los ... con el caracter en cuestión.
        C1 se corresponde con el penúltimo caracter de la primer palabra.
        C2 se corresponde con el penúltimo caracter de la segunda palabra.
        C3 se corresponde con el penúltimo caracter de la tercer palabra.

    Ejemplo:
        Si palabra1 = Hola
        palabra2 = Adios
        palabra3 = Aloha
        La función regresa 'C1 = < l >, C2 = < o > y C3 = < h >' (Ojo con los espacios)

    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código


    # Escribe aquí tu código
    
    return # Escribe aquí tu código

# %%
calificador.califica_mostrar_caracteres(mostrar_caracteres, CORREO, False)

# %%
def concatenar_cadenas(cadena1, cadena2):
    """
    Instrucciones:
        Esta función recibe como parámetros
        dos cadenas llamadas 
        cadena1 y cadena2 respectivamente

        Deberás crear una variable llamada
        cadenas
        que será el resultado de contactenar 
        la cadena1 y la cadena2

    Ejemplo:
        Si cadena1 = "hola, "
        y cadena2 = "mundo"
        cadenas tendra el valor de 'hola, mundo'

    Recuerda:
        Para concatenar cadenas se usa el operador +

    Recuerda:
        Cuida la indentación.

    Observación:
        Aunque este ejercicio se puede hacer con 
        una solución parecida al ejercicio anterior
        usa el operador +
    """

    # Escribe aquí tu código


    # Escribe aquí tu código

    return # Escribe aquí tu código

# %%
calificador.califica_concatenar_cadenas(concatenar_cadenas, CORREO, False)

# %%
def reemplazar_cadenas(cadena_base, cadena_a_reemplazar, cadena_de_reemplazo):
    """
    Instrucciones:
        Esta función recibe como parámetros
        tres cadenas de caracteres:
        cadena_base, cadena_a_reemplazar y cadena_de_reemplazo.
        Reemplaza, de la cadena_base, las sub cadenas que coincidan con 
        cadena_a_reemplazar, con la cadena_de_reemplazo y devuelve la cadena
        nueva con las subcadenas reemplazadas adecuadamente.

    Ejemplo:
        Si cadena_base = "Patio verde",
        cadena_a_reemplazar = "verde"
        y cadena_de_reemplazo = "azul"
        La función devuelve 'Patio azul'

    Nota:
        En python existe una función llamada replace
        que nos va a servir para nuestro cometido. 
        La función replace se usa por medio de una cadena de
        caracteres y recibe otras dos.
        Por ejemplo: "hola".replace("a", "as") devuelve 'holas'.

    Recordatorio:
        Una cadena de caracteres puede guardarse en una variable.
    
    Recordatorio:
        Una cadena de caracteres puede contener sólo un caracter.

    Recordatorio:
        La función replace no modifica la cadena original.
    """

    # Escribe aquí tu código


    # Escribe aquí tu código

    return # Escribe aquí tu código

# %%
calificador.califica_reemplazar_cadenas(reemplazar_cadenas, CORREO, False)

# %%
def reemplazar_y_concatenar(cadena1, cadena2):
    """
    Instrucciones:
        Esta función recibe como parámetros
        dos cadenas de caracteres:
        cadena1 y cadena2
        Reemplaza las letras e o E de la cadena1 con i (minúscula), reemplaza las
        letras a o A de la cadena2 con o (minúscula), concatena las nuevas cadenas
        y devuelve la cadena resultante de la concatenación.
        

    Ejemplo:
        Si cadena1 = "El mar"
        si cadena2 = "La ola"
        La función devuelve il marLoolo

    Consejo:
        Usa la función replace 4 veces.
    """

    # Escribe aquí tu código


    # Escribe aquí tu código

    return # Escribe aquí tu código

# %%
calificador.califica_reemplazar_y_concatenar(reemplazar_y_concatenar, CORREO, False)

# %%
def longitud_de_cadenas(cadena1, cadena2):
    """
    Instrucciones:
        Esta función recibe como parámetros
        dos cadenas llamadas 
        cadena1 y cadena2 respectivamente
        Obtiene la longitud de ambas cadenas
        y devuelve su suma.

    Ejemplo:
        Si cadena1 = "Casa azul"
        y cadena2 = "Historieta"
        la función devuelve un 19

    Nota:
        La función len obtiene la longitu de un
        iterable, como una cadena de caracteres,
        o sea len("Hola") me da un 4
    """

    # Escribe aquí tu código


    # Escribe aquí tu código

    return # Escribe aquí tu código

# %%
calificador.califica_longitud_de_cadenas(longitud_de_cadenas, CORREO, False)

# %%
def peso_de_un_cuerpo(masa):
    """
    Instrucciones:
        Esta función recibe como parámetro
        la masa de un cuerpo en la variable masa
        Deberás calcular el peso de un cuerpo
        con esa masa.
        La formula para calcular el peso de un cuerpo
        es gravedad*masa
        Toma la gravedad de la tierra con un valor de 
        9.81.
        La función devuelve la cadena de caracteres:
        'Tu peso es: ...N' reemplazando los ... con el peso
        obtenido de hacer el cálculo.

    Ejemplo:
        Si masa = 10
        La función devuelve 'Tu peso es: 98.1N"

    Nota: 
        Usa la función round para redondear a 2 decimales.
        
    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código


    # Escribe aquí tu código

    return # Escribe aquí tu código

# %%
calificador.califica_peso_de_un_cuerpo(peso_de_un_cuerpo, CORREO, False)

# %%
def calculo_de_velocidad_constante(distancia, instante_t):
    """
    Instrucciones:
        Esta función recibe como parámetros
        la distancia que recorre un objeto en movimiento
        y el instante de tiempo t en el que se quiere
        medir su velocidad.

        Calcula la velocidad del cuerpo en movimiento
        data la distancia y el instante_t.

        La formula para calcular la velocidad es
        distancia / tiempo.

        Devuelve la cadena de caracteres 'La velocidad es: ...m/s'
        reemplazando los ... con el valor obtenido al hacer el cálculo
        anterior.

    Recuerda:
        Cuida la indentación.
        
    """

    # Escribe aquí tu código


    # Escribe aquí tu código

    return # Escribe aquí tu código

# %%
calificador.califica_calculo_de_velocidad_constante(calculo_de_velocidad_constante, CORREO, False)

# %%
def calculo_de_velocidad_con_aceleracion(velocidad_inicial, aceleracion, instante_t):
    """
    Instrucciones:
        Esta función recibe como parámetros
        la velocidad inicial, la aceleracion
        y un instante t
        de un cuerpo en movimiento uniformemente
        acelerado.

        Calcula la velocidad del cuerpo en movimiento
        dada su velocidad inicial y aceleracion 
        en el tiempo t.

        La fórmula para calcular la velocidad de un cuerpo
        en movimiento con aceleración constante es:
        velocidad_inicial + aceleracion * tiempo.

        Devuelve la cadena de caracteres 'La velocidad es: ... m/s',
        reemplazando los ... con el resultado del cálculo anterior.

    Recuerda:
        Cuida la indentación.
        
    """

    # Escribe aquí tu código


    # Escribe aquí tu código

    return # Escribe aquí tu código
