# %% [markdown]
# <center><img src="Analitica delfos-06.jpg" width="200" height="160" style="margin:auto"/></center>

# %%
#
#
# EJECUTAR ESTA CELDA CADA VEZ QUE ENTRES A HACER LA TAREA
#
#

#####################################
# Regresión logística
#####################################

import numpy as np
from sklearn.linear_model import LogisticRegression
import calificador
from controlador import Controlador

# %%
@Controlador("2", "ejercicio_6")
def ejercicio_6(x_entrenamiento, y_entrenamiento, x_nuevo):
    """
    Instrucciones:
        Esta función recibe:

        x_entrenamiento (array bidimensional): variables independientes de entrenamiento.

        y_entrenamiento (array): etiquetas binarias (0 o 1).

        x_nuevo (array o lista): nueva observación a clasificar.

        Debe entrenar un modelo de regresión logística (sklearn.linear_model.LogisticRegression) con los datos y devolver la clase predicha (0 o 1) para x_nuevo.
    
    Usar un random_state de la regresión logística de 21

    Recuerda:
        Lo que la función "regresa" es justo lo que va después
        de la palabra reservada return

        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_6(ejercicio_6)

# %%
@Controlador("2", "ejercicio_7")
def ejercicio_7(x_entrenamiento, y_entrenamiento, x_nuevo):
    """
    Instrucciones:
        Esta función recibe:

        x_entrenamiento (array bidimensional): variables independientes.

        y_entrenamiento (array): etiquetas binarias (0 o 1).

        x_nuevo (array o lista): nueva observación.

        Debe entrenar un modelo de regresión logística y retornar la probabilidad estimada de pertenecer a la clase 1, redondeada a dos decimales.

    Usar un random_state de la regresión logística de 21
    
    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_7(ejercicio_7)

# %%
@Controlador("2", "ejercicio_8")
def ejercicio_8(x, y):
    """
    Instrucciones:
        Esta función recibe:

        x (array bidimensional): variables independientes.

        y (array): etiquetas binarias.

        Debe entrenar el modelo de regresión logística con los datos completos y retornar la precisión (accuracy) sobre el mismo conjunto, redondeada a dos decimales.

    Usar un random_state de la regresión logística de 21
    
    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_8(ejercicio_8)

# %%
@Controlador("2", "ejercicio_9")
def ejercicio_9(x, y):
    """
    Instrucciones:
        x (array bidimensional): variables independientes.

        y (array): etiquetas binarias.

        Debe entrenar un modelo de regresión logística y devolver un arreglo de numpy con los coeficientes, redondeados a dos decimales.

    Usar un random_state de la regresión logística de 21

    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_9(ejercicio_9)

# %%
@Controlador("2", "ejercicio_10")
def ejercicio_10(x_entrenamiento, y_entrenamiento, x_nuevos):
    """
    Instrucciones:
        Esta función recibe:

        x_entrenamiento (array bidimensional): variables independientes de entrenamiento.

        y_entrenamiento (array): etiquetas binarias de entrenamiento.

        x_nuevos (array bidimensional): nuevos datos para clasificar.

        Debe entrenar el modelo y devolver un arreglo de numpy con las probabilidades de clase 1 para cada observación, redondeadas a dos decimales.
        
    Usar un random_state de la regresión logística de 21
    
    Recuerda:
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return  # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_10(ejercicio_10)
