# %% [markdown]
# <center><img src="Analitica delfos-06.jpg" width="200" height="160" style="margin:auto"/></center>

# %%
#
#
# EJECUTAR ESTA CELDA CADA VEZ QUE ENTRES A HACER LA TAREA
#
#

#####################################
#       Escaladores
#####################################


import calificador
from controlador import Controlador
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler

# %%
@Controlador("4", "ejercicio_16")
def ejercicio_16(x):
    """
    Instrucciones:
        Esta función recibe:

        x (array bidimensional o lista de listas): matriz de características numéricas.

        Debe aplicar el escalador StandardScaler de sklearn, 
        transformar los datos y retornar el arreglo escalado con los valores redondeados a dos decimales.

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_16(ejercicio_16)

# %%
@Controlador("4", "ejercicio_17")
def ejercicio_17(x, rango):
    """
    Instrucciones:
        Esta función recibe:

        x (array bidimensional o lista de listas): matriz de valores numéricos.

        rango (tupla con dos floats): límite inferior y superior del nuevo rango, por ejemplo (0, 1) o (-1, 1).

        Debe aplicar MinMaxScaler usando el rango indicado y devolver el arreglo escalado, redondeado a dos decimales.

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_17(ejercicio_17)

# %%
@Controlador("4", "ejercicio_18")
def ejercicio_18(x):
    """
     Instrucciones:
        Esta función recibe:

        x (array bidimensional o lista de listas): matriz de valores numéricos.

        Debe aplicar el escalador MaxAbsScaler, que divide cada valor por el máximo absoluto de su columna, y devolver el arreglo escalado, redondeado a dos decimales.

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_18(ejercicio_18)

# %%
@Controlador("4", "ejercicio_19")
def ejercicio_19(x):
    """
    Instrucciones:
        Esta función recibe:

        x (array bidimensional o lista de listas): matriz de valores numéricos.

        Debe aplicar RobustScaler, que escala usando la mediana y el rango intercuartil, y devolver el arreglo escalado con los valores redondeados a dos decimales.
    
    """

    # Escribe aquí tu código ↓


    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_19(ejercicio_19)

# %%
@Controlador("4", "ejercicio_20")
def ejercicio_20(x):
    """
    Instrucciones:
        Esta función recibe:

        x (array bidimensional o lista de listas): matriz de valores numéricos.

        Debe aplicar StandardScaler y MinMaxScaler sobre los mismos datos, 
        calcular la diferencia promedio absoluta entre ambas transformaciones, 
        y devolver ese valor como un solo número redondeado a dos decimales.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_20(ejercicio_20)
