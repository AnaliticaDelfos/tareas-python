# %% [markdown]
# <center><img src="Analitica delfos-06.jpg" width="200" height="160" style="margin:auto"/></center>

# %%
#
#
# EJECUTAR ESTA CELDA CADA VEZ QUE ENTRES A HACER LA TAREA
#
#

#####################################
#       Máquinas de soporte vectorial
#####################################


import calificador
from controlador import Controlador
import numpy as np
from sklearn.svm import SVC

# %%
@Controlador("3", "ejercicio_11")
def ejercicio_11(x_entrenamiento, y_entrenamiento, x_nuevo):
    """
    Instrucciones:
        Esta función recibe:

        x_entrenamiento (array bidimensional): variables independientes de entrenamiento.

        y_entrenamiento (array): etiquetas binarias (0 o 1).

        x_nuevo (array o lista): nueva observación para clasificar.

        Debe entrenar un modelo de SVM lineal (sklearn.svm.SVC, con kernel linear) y devolver la clase predicha (0 o 1) para x_nuevo.

    Usar un random_state de la máquina de soporte vectorial de 21

    Recuerda:
        Lo que la función "regresa" es justo lo que
        va después de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return  # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_11(ejercicio_11)

# %%
@Controlador("3", "ejercicio_12")
def ejercicio_12(x_entrenamiento, y_entrenamiento, x_nuevo):
    """
    Instrucciones:
        Esta función recibe:

            x_entrenamiento (array bidimensional): variables independientes.

            y_entrenamiento (array): etiquetas binarias (0 o 1).

            x_nuevo (array o lista): nueva observación.

            Debe entrenar un modelo SVM con kernel RBF y probability=True, y devolver la probabilidad de pertenecer a la clase 1, redondeada a dos decimales.
            
            Además de redondear debes regresar un número de tipo float, no np.float

    Usar un random_state de la máquina de soporte vectorial de 21

    Recuerda:
        Lo que la función "regresa" es justo lo que
        va después de la palabra reservada "return".
        
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_12(ejercicio_12)

# %%
@Controlador("3", "ejercicio_13")
def ejercicio_13(x, y):
    """
    Instrucciones:
        Esta función recibe:

            x (array bidimensional): variables independientes.

            y (array): etiquetas binarias.

            Debe entrenar un modelo SVM lineal (kernel='linear') y devolver el accuracy sobre el mismo conjunto de entrenamiento, redondeada a dos decimales.

    Usar un random_state de la máquina de soporte vectorial de 21

    Recuerda:
        Lo que la función "regresa" es justo lo que
        va después de la palabra reservada "return".
        
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_13(ejercicio_13)

# %%
@Controlador("3", "ejercicio_14")
def ejercicio_14(x_entrenamiento, y_entrenamiento, x_prueba):
    """
    Instrucciones:
        Esta función recibe:

        x_entrenamiento (array bidimensional): variables independientes de entrenamiento.

        y_entrenamiento (array): etiquetas binarias.

        x_prueba (array bidimensional): datos a evaluar.

        Debe entrenar un modelo SVM lineal (kernel='linear') y devolver un arreglo de numpy con los valores de la función de decisión (distancia al hiperplano) para cada observación de x_prueba, redondeados a dos decimales.

    Usar un random_state de la máquina de soporte vectorial de 21        

    Tip:
        La función de decisión se encuentra en el método decision_function de las máquinas de soporte vectorial
        y le vas a dar el conjunto de prueba.        

    Recuerda:
        Lo que la función "regresa" es justo lo que
        va después de la palabra reservada "return".
        
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_14(ejercicio_14)

# %%
@Controlador("3", "ejercicio_15")
def ejercicio_15(x_entrenamiento, y_entrenamiento, x_nuevos):
    """
     Instrucciones:
        Esta función recibe:

        x_entrenamiento (array bidimensional): variables independientes de entrenamiento.

        y_entrenamiento (array): etiquetas binarias de entrenamiento.

        x_nuevos (array bidimensional): nuevos datos para clasificar.

        Debe entrenar un modelo SVM con kernel polinomial (kernel='poly', grado 3) y devolver un arreglo de numpy con las clases predichas (0 o 1) para las observaciones de x_nuevos.


    Recuerda:
        Lo que la función "regresa" es justo lo que
        va después de la palabra reservada "return".
        
        Cuida la indentación.
    """

    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_ml_15(ejercicio_15)
