# %%
#
#
# EJECUTAR ESTA CELDA CADA VEZ QUE ENTRES A HACER LA TAREA
#
#

#####################################
# Condicionales
#####################################


import calificador
from controlador import Controlador

# %% [markdown]
# A partir de ahora no te proveemos de una celda con un ejemplo, no es algo por lo qué ponerse triste, una parte importante en la vida de un programador es que es capaz de verificar que su código está bien hecho dada una entrada y esperando una salida, por ejemplo, supongamos que haces un programa que recibe dos números y devuelve la suma de ellos, en este caso un programador debe poder al menos un caso en el que conozca tanto las entradas como el resultado esperado, es decir, podría probar que si le da a su función un 2 y un 3 su función debe contestar con un 5.
#
# Justo lo anterior es lo que esperamos que desarrolles, esa habilidad de crear tus propias pruebas dados tus propios códigos, por eso les decimos algo como "Cuando estés listo para que se califique tu función porque crees que resuelve el problema, mándala calificar", queremos que desarrolles esa habilidad, sólo así sabrás que tu código está bien hecho y que entendiste realmente el problema que estás tratando de resolver.
#
# Adicionalmente recuerda que puedes agregar las celdas que gustes, también puedes borrarlas en caso que no te gusten, sólo recuerda no borrar las celdas donde se define la función, donde se manda a calificar y la primer celda, fuera de eso, puedes hacer lo que tu quieras :)
#
# Algunos tips que te pueden funcionar son los siguientes:
# - Analiza los valores extremos o en la frontera (cuál es el último o primer valor para el que mi función hace lo que tiene que hacer?)
# - Verifica casos chiquitos perfectamente conocidos para ti (una suma de 2 y 2 me debe dar 4).
# - Prueba más de un caso chiquito.
# - Verifica cómo se comporta tu función tomando valores admitidos, pero de diferente dominio (una suma de 2 y -2 me debe dar 0).
# - Analiza para cuales tipos de datos tu función hace lo que tiene que hacer y para cuales no ([1] + 1 = [1, 1], pero 1 + 1 = 2).
# - Esto que te digo sale de una metodología llamada "Test driven development" por si quieres saber más :)
#
# También queremos que recuerdes que no estás solo, estamos para apoyarte en cualquier duda que tengas.

# %%
@Controlador("6", "ejercicio_51")
def ejercicio_51(a, b):
    """
    Instrucciones:
        La función "ejercicio_51" toma los parametros "a", "b", y  
        debe regresar el valor de verdad que resulte tras operarlos
        con el operador lógico "or".

    Condiciones:
        Los parametros "a" y "b" pueden ser cualquier objeto al
        que le corresponda un valor de verdad (basta con utilizar 
        el operador "bool" para obtener dicho valor) o bien, los valores
        de verdad mismos (True o False).

    Ejemplo:
        Si  a=True y b=False la función regresa:
        True

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_51(ejercicio_51)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_51 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 4
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [True, True].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [True, False].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [False, True].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [False, False].             Valor esperado: False.             Valor obtenido: False
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_52")
def ejercicio_52(a, b):
    """
    Instrucciones:
        La función "ejercicio_52" toma los parametros "a", "b", y  
        debe realizar bit a bit la operación 'XOR' en los operandos
        correspondientes a "a" y "b" para regresar el valor resultante.

    Condiciones:
        Revisa el operador bit a bit "^".
        
        Los parametros "a" y "b" deben ser números enteros (int) o 
        números en binario.

    Ejemplo:
        Si  a=18 y b=32 la función regresa:
        50

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_52(ejercicio_52)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_52 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [18, 32].             Valor esperado: 50.             Valor obtenido: 50
#
# Valores de entrada: [-64, 18].             Valor esperado: -46.             Valor obtenido: -46
#
# Valores de entrada: [72, -33].             Valor esperado: -105.             Valor obtenido: -105
#
# Valores de entrada: [2, -3].             Valor esperado: -1.             Valor obtenido: -1
#
# Valores de entrada: [-1, 2].             Valor esperado: -3.             Valor obtenido: -3
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_53")
def ejercicio_53(x, y):
    """
    Instrucciones:
        La función "ejercicio_53" toma los parametros "x", "y", y  
        debe regresar el valor de verdad True si el operador de la 
        izquierda es mayor que el operador de la derecha

    Condiciones:
        Revisa el operador relacional ">".
        
        Los parametros "x" y "y" deben ser números enteros (int) o 
        números decimales (float).

    Ejemplo:
        Si  x=6.3 y y=3 la función regresa:
        True

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
     

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_53(ejercicio_53)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_53 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [6.3, 3].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [3, 1].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [1, 3].             Valor esperado: False.             Valor obtenido: False
#
# Valores de entrada: [3.5, 2.5].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [2.5, 3.5].             Valor esperado: False.             Valor obtenido: False
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_54")
def ejercicio_54(x, y):
    """
    Instrucciones:
        La función "ejercicio_54" toma los parametros "x", "y", y  
        debe regresar el valor de verdad True si el operador de la 
        izquierda es mayor o igual que el operador de la derecha.

    Condiciones:
        Revisa el operador relacional ">=".
        
        Los parametros "x" y "y" deben ser números enteros (int) o 
        números decimales (float).

    Ejemplo:
        Si  x=7.8 y y=2 la función regresa:
        True

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_54(ejercicio_54)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_54 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 80.0
#             ||          Aciertos: 4
#             ||          Errores: 1
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [7.8, 2].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [3, 2].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [1, 2].             Valor esperado: False.             Valor obtenido: False
#
# Valores de entrada: [3, 1.3].             Valor esperado: True.             Valor obtenido: True
#
# ======> Casos con error <======
#
# Valores de entrada: [2.5, 1.5].             Valor esperado: False.             Valor obtenido: True
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_55")
def ejercicio_55(x, y):
    """
    Instrucciones:
        La función "ejercicio_55" toma los parametros "x", "y", y  
        debe regresar el resultado en número entero de dividir el 
        operando "x" entre el operando "y".

    Condiciones:
        Revisa el operador aritmético "//".
        
        Los parametros "x" y "y" deben ser números enteros (int) o 
        números decimales (float).

    Ejemplo:
        Si  x=3.3 y y=3 la función regresa:
        1.0

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_55(ejercicio_55)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_55 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
# Valores de entrada: [3.3, 3].             Valor esperado: 1.0.             Valor obtenido: 1.0
#
# Valores de entrada: [18, 5].             Valor esperado: 3.             Valor obtenido: 3
#
# Valores de entrada: [2.5, 1.2].             Valor esperado: 2.0.             Valor obtenido: 2.0
#
# Valores de entrada: [15, 2.5].             Valor esperado: 6.0.             Valor obtenido: 6.0
#
# Valores de entrada: [2, 2].             Valor esperado: 1.             Valor obtenido: 1
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_56")
def ejercicio_56(a):
    """
    Instrucciones:
        La función "ejercicio_56" toma el parámetro "a" y, 
        debe regresar la cadena de caracteres "Bienvenido
        a tu país" si dicho parámetro corresponde a la cadena
        "México", además debe regresar la cadena "Bienvenido a México"
        en caso de que "a" corresponda a una cadena de caracteres 
        de cualquier otro país.

    Condiciones:
       El parámetro "a" debe ser una cadena de caracteres que
       corresponda al nombre de algún país.

    Ejemplo:
        Si  a="Francia" la función regresa:
        Bienvenido a México.

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    
    
    # Escribe aquí tu código ↑

# %%
calificador.califica_ejercicio_56(ejercicio_56)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_56 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
#  Valores de entrada: México.              Valor esperado: Bienvenido a tu país.              Valor obtenido: Bienvenido a tu país
#
#  Valores de entrada: España.              Valor esperado: Bienvenido a México.              Valor obtenido: Bienvenido a México
#
#  Valores de entrada: Francia.              Valor esperado: Bienvenido a México.              Valor obtenido: Bienvenido a México
#
#  Valores de entrada: Italia.              Valor esperado: Bienvenido a México.              Valor obtenido: Bienvenido a México
#
#  Valores de entrada: Colombia.              Valor esperado: Bienvenido a México.              Valor obtenido: Bienvenido a México
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_57")
def ejercicio_57(x):
    """
    Instrucciones:
        La función "ejercicio_57" toma el parámetro "x" y,  
        debe regresar la cadena de caracteres "Dentro de rango" 
        si es que el número correspondiente a "x" se encuentra
        en el rango de 15 a 25 (incluyendo el 15 y el 25) y la
        cadena "Fuera de rango" en caso contrario.

    Condiciones:
        El parámetro "x" debe ser un numero entero (int).

    Ejemplo:
        Si  x=17 la función regresa:
        Dentro de rango

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

# %%
calificador.califica_ejercicio_57(ejercicio_57)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_57 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 8
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 17.              Valor esperado: Dentro de rango.              Valor obtenido: Dentro de rango
#
#  Valores de entrada: 14.              Valor esperado: Fuera de rango.              Valor obtenido: Fuera de rango
#
#  Valores de entrada: 26.              Valor esperado: Fuera de rango.              Valor obtenido: Fuera de rango
#
#  Valores de entrada: 20.              Valor esperado: Dentro de rango.              Valor obtenido: Dentro de rango
#
#  Valores de entrada: 50.              Valor esperado: Fuera de rango.              Valor obtenido: Fuera de rango
#
#  Valores de entrada: 1.              Valor esperado: Fuera de rango.              Valor obtenido: Fuera de rango
#
#  Valores de entrada: 15.              Valor esperado: Dentro de rango.              Valor obtenido: Dentro de rango
#
#  Valores de entrada: 25.              Valor esperado: Dentro de rango.              Valor obtenido: Dentro de rango
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_58")
def ejercicio_58(x):
    """
    Instrucciones:
        La función "ejercicio_58" toma el parámetro "x" y,  
        debe regresar la cadena de caracteres "Pase" 
        si es que el número correspondiente a "x" es mayor
        o igual a 18, en caso contrario se debe mostrar la 
        cadena "Acceso denegado".

    Condiciones:
        El parámetro "x" debe ser un numero entero (int).

    Ejemplo:
        Si  x=15 la función regresa:
        Acceso denegado

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    
    
    # Escribe aquí tu código ↑

# %%
calificador.califica_ejercicio_58(ejercicio_58)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_58 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 15.              Valor esperado: Acceso denegado.              Valor obtenido: Acceso denegado
#
#  Valores de entrada: 10.              Valor esperado: Acceso denegado.              Valor obtenido: Acceso denegado
#
#  Valores de entrada: 18.              Valor esperado: Pase.              Valor obtenido: Pase
#
#  Valores de entrada: 100.              Valor esperado: Pase.              Valor obtenido: Pase
#
#  Valores de entrada: -2.              Valor esperado: Acceso denegado.              Valor obtenido: Acceso denegado
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_59")
def ejercicio_59(x):
    """
    Instrucciones:
        La función "ejercicio_59" toma el parámetro "x" y,  
        debe regresar la cadena de caracteres "No es seguro
        el acceso" si es que el número correspondiente a "x" 
        es menor a 1.5, en caso contrario se debe mostrar la 
        cadena "Adelante".

    Condiciones:
        El parámetro "x" debe ser un numero decimal (float) que
        simula la estatura en metros.

    Ejemplo:
        Si  x=1.5 la función regresa:
        Adelante

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑

# %%
calificador.califica_ejercicio_59(ejercicio_59)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_59 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 4
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 1.5.              Valor esperado: Adelante.              Valor obtenido: Adelante
#
#  Valores de entrada: 1.4.              Valor esperado: No es seguro el acceso.              Valor obtenido: No es seguro el acceso
#
#  Valores de entrada: 1.35.              Valor esperado: No es seguro el acceso.              Valor obtenido: No es seguro el acceso
#
#  Valores de entrada: 1.6.              Valor esperado: Adelante.              Valor obtenido: Adelante
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_60")
def ejercicio_60(a):
    """
    Instrucciones:
        La función "ejercicio_60" toma el parámetro "a" y,  
        debe regresar la cadena de caracteres "Lindo color :)"
        si "a" es distinto de la cadena de caracteres "Azul"
        y debe regresar la cadena "Azul como el cielo" en 
        caso contrario.
        
    Condiciones:
        El parámetro "a" debe ser una cadena de caracteres (str)
        que sea igual a el nombre de algún color. 

    Ejemplo:
        Si a="Rojo" la función regresa:
        Lindo color :)

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    
    
    # Escribe aquí tu código ↑

# %%
calificador.califica_ejercicio_60(ejercicio_60)
# Out:
# ===============================================================================
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_60 <============
#
# ===============================================================================
#
#
# ======================================================
#             ||          Calificación: 100.0
#             ||          Aciertos: 4
#             ||          Errores: 0
# ======================================================
#
# ======> Casos existosos: <======
#
#  Valores de entrada: Azul.              Valor esperado: Azul como el cielo.              Valor obtenido: Azul como el cielo
#
#  Valores de entrada: Rojo.              Valor esperado: Lindo color :).              Valor obtenido: Lindo color :)
#
#  Valores de entrada: Verde.              Valor esperado: Lindo color :).              Valor obtenido: Lindo color :)
#
#  Valores de entrada: Amarillo.              Valor esperado: Lindo color :).              Valor obtenido: Lindo color :)
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============
