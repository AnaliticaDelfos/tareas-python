# %%
#
#
# EJECUTAR ESTA CELDA CADA VEZ QUE ENTRES A HACER LA TAREA
#
#

#####################################
# Condicionales
#####################################


import calificador
from controlador import Controlador

# %% [markdown]
# A partir de ahora no te proveemos de una celda con un ejemplo, no es algo por lo qué ponerse triste, una parte importante en la vida de un programador es que es capaz de verificar que su código está bien hecho dada una entrada y esperando una salida, por ejemplo, supongamos que haces un programa que recibe dos números y devuelve la suma de ellos, en este caso un programador debe poder al menos un caso en el que conozca tanto las entradas como el resultado esperado, es decir, podría probar que si le da a su función un 2 y un 3 su función debe contestar con un 5.
#
# Justo lo anterior es lo que esperamos que desarrolles, esa habilidad de crear tus propias pruebas dados tus propios códigos, por eso les decimos algo como "Cuando estés listo para que se califique tu función porque crees que resuelve el problema, mándala calificar", queremos que desarrolles esa habilidad, sólo así sabrás que tu código está bien hecho y que entendiste realmente el problema que estás tratando de resolver.
#
# Adicionalmente recuerda que puedes agregar las celdas que gustes, también puedes borrarlas en caso que no te gusten, sólo recuerda no borrar las celdas donde se define la función, donde se manda a calificar y la primer celda, fuera de eso, puedes hacer lo que tu quieras :)
#
# Algunos tips que te pueden funcionar son los siguientes:
# - Analiza los valores extremos o en la frontera (cuál es el último o primer valor para el que mi función hace lo que tiene que hacer?)
# - Verifica casos chiquitos perfectamente conocidos para ti (una suma de 2 y 2 me debe dar 4).
# - Prueba más de un caso chiquito.
# - Verifica cómo se comporta tu función tomando valores admitidos, pero de diferente dominio (una suma de 2 y -2 me debe dar 0).
# - Analiza para cuales tipos de datos tu función hace lo que tiene que hacer y para cuales no ([1] + 1 = [1, 1], pero 1 + 1 = 2).
# - Esto que te digo sale de una metodología llamada "Test driven development" por si quieres saber más :)
#
# También queremos que recuerdes que no estás solo, estamos para apoyarte en cualquier duda que tengas.

# %%
@Controlador("6", "ejercicio_51")
def ejercicio_51(x, y):
    """
    Instrucciones:
        La función "ejercicio_51" toma los parametros "x", "y", y  
        debe regresar el valor de verdad True si es que ambos 
        operandos no se refieren al mismo objeto, de caso contrario
        regresará False.

    Condiciones:
        Los parametros "x" y "y" son operandos cuya identidad se 
        va a evaluar por medio del operador de identidad "is not".

    Ejemplo:
        Si  x=5 y y=5  la función regresa:
        False

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_51(ejercicio_51)
# Out:
# ...
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_51 <============
#
# ...
#
#
# ...
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ...
#
# ======> Casos existosos: <======
#
# Valores de entrada: [5, 5].             Valor esperado: False.             Valor obtenido: False
#
# Valores de entrada: ['Hola', 'Hola'].             Valor esperado: False.             Valor obtenido: False
#
# Valores de entrada: [1, 1.2].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: ['Mi nombre es', 'Soy'].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [1.0, 1].             Valor esperado: True.             Valor obtenido: True
#
# ======> No hubo errores :D <======
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ...

# %%
@Controlador("6", "ejercicio_52")
def ejercicio_52(x):
    """
    Instrucciones:
        La función "ejercicio_52" toma el parámetro "x" y  
        debe regresar el valor de verdad contrario al del 
        objeto correspondiente a "x".

    Condiciones:
        El parámetro "x" es un operando con un objeto al que
        le corresponde algún valor de verdad (True o False),
        se regreserá el valor contrario a este por medio del
        operador atómico "not".

    Ejemplo:
        Si  x="Hola" la función regresa:
        False

    Recuerda:
        Puedes utilizar el operador "bool" para obtener el 
        valor de verdad de los elementos que reciba la función 
        como argumento.

        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_52(ejercicio_52)
# Out:
# ...
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_52 <============
#
# ...
#
#
# ...
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ...
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 2.              Valor esperado: False.              Valor obtenido: False
#
#  Valores de entrada: 20.1.              Valor esperado: False.              Valor obtenido: False
#
#  Valores de entrada: Hola.              Valor esperado: False.              Valor obtenido: False
#
#  Valores de entrada: .              Valor esperado: True.              Valor obtenido: True
#
#  Valores de entrada: 0.              Valor esperado: True.              Valor obtenido: True
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_53")
def ejercicio_53(a):
    """
     Instrucciones:
        La función "ejercicio_53" toma el parámetro "a" y  
        realiza bit a bit la operación 'NOT' bit a bit. 
        Invierte cada bit en el operando correspondiente al
        parámetro "a"

    Condiciones:
        Revisa el operador bit a bit "~".

        El parámetro "a" debe ser un número entero (int) o 
        un número en binario.

    Ejemplo:
        Si  a=64 la función regresa:
        -65

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
     

    # Escribe aquí tu código ↑ 
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_53(ejercicio_53)
# Out:
# ...
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_53 <============
#
# ...
#
#
# ...
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ...
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 64.              Valor esperado: -65.              Valor obtenido: -65
#
#  Valores de entrada: 32.              Valor esperado: -33.              Valor obtenido: -33
#
#  Valores de entrada: 110100.              Valor esperado: -110101.              Valor obtenido: -110101
#
#  Valores de entrada: -5.              Valor esperado: 4.              Valor obtenido: 4
#
#  Valores de entrada: -99.              Valor esperado: 98.              Valor obtenido: 98
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_54")
def ejercicio_54(x, y):
    """
    Instrucciones:
        La función "ejercicio_54" toma los parametros "x", "y", y  
        debe regresar el valor de verdad True si el operador de la 
        izquierda es menor que el operador de la derecha.

    Condiciones:
        Revisa el operador relacional "<".
        
        Los parametros "x" y "y" deben ser números enteros (int) o 
        números decimales (float).

    Ejemplo:
        Si  x=3 y y=6.5 la función regresa:
        True

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_54(ejercicio_54)
# Out:
# ...
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_54 <============
#
# ...
#
#
# ...
#             ||          Calificación: 80.0
#             ||          Aciertos: 4
#             ||          Errores: 1
# ...
#
# ======> Casos existosos: <======
#
# Valores de entrada: [3, 6.5].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [6.5, 3].             Valor esperado: False.             Valor obtenido: False
#
# Valores de entrada: [-3.3, 1].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [1, 2].             Valor esperado: True.             Valor obtenido: True
#
# ======> Casos con error <======
#
#  Valores de entrada: -1.5.              Valor esperado: False.              Valor obtenido: None
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_55")
def ejercicio_55(x, y):
    """
    Instrucciones:
        La función "ejercicio_55" toma los parametros "x", "y", y  
        debe regresar el valor de verdad True si los operadores "x"
        y "y" son distintos entre sí y False en caso contrario.

    Condiciones:
        Revisa el operador relacional "!=".
        
        Los parametros "x" y "y" deben ser números enteros (int) o 
        números decimales (float).

    Ejemplo:
        Si  x=1.2 y y=1.2 la función regresa:
        False

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
    return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_55(ejercicio_55)
# Out:
# ...
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_55 <============
#
# ...
#
#
# ...
#             ||          Calificación: 100.0
#             ||          Aciertos: 5
#             ||          Errores: 0
# ...
#
# ======> Casos existosos: <======
#
# Valores de entrada: [1.2, 1.2].             Valor esperado: False.             Valor obtenido: False
#
# Valores de entrada: [1, 1].             Valor esperado: False.             Valor obtenido: False
#
# Valores de entrada: [3.5, 2].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [6, 3.2].             Valor esperado: True.             Valor obtenido: True
#
# Valores de entrada: [2, 1].             Valor esperado: True.             Valor obtenido: True
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_56")
def ejercicio_56(a):
    """
    Instrucciones:
        La función "ejercicio_56" toma el parámetro "a"
        y regresa la cadena de carácteres "Incluido" si
        "a" es menor que 10.

    Condiciones: 
        El parámetro "a" debe ser un número entero.

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
        return  # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_56(ejercicio_56)
# Out:
# ...
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_56 <============
#
# ...
#
#
# ...
#             ||          Calificación: 40.0
#             ||          Aciertos: 2
#             ||          Errores: 3
# ...
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 4.              Valor esperado: Incluido.              Valor obtenido: Incluido
#
#  Valores de entrada: 0.              Valor esperado: Incluido.              Valor obtenido: Incluido
#
# ======> Casos con error <======
#
#  Valores de entrada: 10.              Valor esperado: Incluido.              Valor obtenido: None
#
#  Valores de entrada: 11.              Valor esperado: No incluido.              Valor obtenido: None
#
#  Valores de entrada: 15.              Valor esperado: No incluido.              Valor obtenido: None
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_57")
def ejercicio_57(a):
    """
    Instrucciones:
        La función "ejercicio_57" toma el parámetro "a" y, 
        debe regresar la cadena de caracteres "Adelante, bienvenido" 
        si dicho parámetro corresponde a la cadena "Invitado"

    Condiciones:
       El parámetro "a" debe ser una cadena de caracteres.

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    
    
    # Escribe aquí tu código ↑
    
        return 
    # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_57(ejercicio_57)
# Out:
# ...
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_57 <============
#
# ...
#
#
# ...
#             ||          Calificación: 50.0
#             ||          Aciertos: 1
#             ||          Errores: 1
# ...
#
# ======> Casos existosos: <======
#
#  Valores de entrada: Invitado.              Valor esperado: Adelante, bienvenido.              Valor obtenido: Adelante, bienvenido
#
# ======> Casos con error <======
#
#  Valores de entrada: No invitado.              Valor esperado: Invitación no encontrada.              Valor obtenido: None
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_58")
def ejercicio_58(x):
    """
    Instrucciones:
        La función "ejercicio_58" toma el parámetro "x" y,  
        debe regresar la cadena de caracteres "Buen día" 
        si es que el número correspondiente a "x" es menor
        que 12.

    Condiciones:
        El parámetro "x" debe ser un numero entero (int).

    Ejemplo:
        Si  x=4 la función regresa:
        Buen día

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    
    
    # Escribe aquí tu código ↑
    
        return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_58(ejercicio_58)
# Out:
# ...
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_58 <============
#
# ...
#
#
# ...
#             ||          Calificación: 40.0
#             ||          Aciertos: 2
#             ||          Errores: 3
# ...
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 0.              Valor esperado: Buen día.              Valor obtenido: Buen día
#
#  Valores de entrada: 10.              Valor esperado: Buen día.              Valor obtenido: Buen día
#
# ======> Casos con error <======
#
#  Valores de entrada: 12.              Valor esperado: Buen día.              Valor obtenido: None
#
#  Valores de entrada: -2.              Valor esperado: Formato incorrecto.              Valor obtenido: Buen día
#
#  Valores de entrada: 11.              Valor esperado: Formato incorrecto.              Valor obtenido: Buen día
#
# ============> Calificación recibida <============

# %%
@Controlador("6", "ejercicio_59")
def ejercicio_59(x):
    """
    Instrucciones:
        La función "ejercicio_59" toma el parámetro "x" y,  
        debe regresar la cadena de caracteres "Aprobado" 
        si es que el número correspondiente a "x" es mayor
        a 5.

    Condiciones:
        El parámetro "x" debe ser un numero entero (int).

    Ejemplo:
        Si x=6 la función regresa:
        Aprobado

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
        return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_59(ejercicio_59)

# %%
@Controlador("6", "ejercicio_60")
def ejercicio_60(x, y, z):
    """
    Instrucciones:
        La función "ejercicio_60" toma los parametros "x", "y", "z"
        y los suma, si el resultado de esa suma es menor que 50 regresa
        la cadena de caracteres "Menos que 50".

    Condiciones:
        Los parametros "x", "y", "z" deben ser números enteros (int).

    Ejemplo:
        Si  x=20,  y=1 y z=5 la función regresa:
        Menos que 50

    Recuerda:
        Lo que la función "regresa" es justo lo que va después 
        de la palabra reservada "return".
        
        Cuida la indentación.
    """
    
    # Escribe aquí tu código ↓
    

    # Escribe aquí tu código ↑
    
        return # ← Escribe aquí tu código

# %%
calificador.califica_ejercicio_60(ejercicio_60)
# Out:
# ...
#
# ============> Calificando: tarea 6 - ejercicio ejercicio_60 <============
#
# ...
#
#
# ...
#             ||          Calificación: 50.0
#             ||          Aciertos: 2
#             ||          Errores: 2
# ...
#
# ======> Casos existosos: <======
#
# Valores de entrada: [1, 2, 3].             Valor esperado: Menos que 50.             Valor obtenido: Menos que 50
#
# Valores de entrada: [40, 1, 1].             Valor esperado: Menos que 50.             Valor obtenido: Menos que 50
#
# ======> Casos con error <======
#
# Valores de entrada: [1, 30, 30].             Valor esperado: Más que 50.             Valor obtenido: None
#
# Valores de entrada: [20, 20, 25].             Valor esperado: Más que 50.             Valor obtenido: None
#
# ============> Calificación recibida <============
