# %%
#
#
# EJECUTAR ESTA CELDA CADA VEZ QUE ENTRES A HACER LA TAREA
#
#

#####################################
#  Ciclos
#####################################


import calificador
from controlador import Controlador

# %%
@Controlador("5", "ejercicio_pyg_25")
def ejercicio_5_21(lista: list):
    """
    Instrucciones:
        Esta función recibe una lista de números.

        Debes usar un ciclo for para recorrer
        la lista y calcular la suma de los cuadrados de todos
        los elementos.

    Ejemplo:
        Si lista = [1, 2, 3, 4]

        la función debe regresar 30

    Pista:
        Usa una variable acumuladora.
    
    Consejo:
        Usa el operador **2 para elevar al cuadrado.
        
    Ejemplo:
        2**2 es igual a 4
    """

    # Código respuesta


    # Código respuesta

    return

# %%
ejercicio_5_21([-1,2,-3,4,-5,100])

# %%
calificador.califica_ejercicio_pyg_21(ejercicio_5_21)

# %%
@Controlador("5", "ejercicio_pyg_26")
def ejercicio_5_22(lista: list):
    """
    Instrucciones:
        Esta función recibe una lista de números.

        Debes contar cuántos números
        son mayores que 10.

    Ejemplo:
        Si lista = [5, 12, 8, 20, 3]

        la función debe regresar 2
    """

    # Código respuesta


    # Código respuesta

    return

# %%
ejercicio_5_22([30,21,18,1,0,12,11])

# %%
calificador.califica_ejercicio_pyg_22(ejercicio_5_22)

# %%
@Controlador("5", "ejercicio_pyg_27")
def ejercicio_5_23(lista: list):
    """
    Instrucciones:
        Esta función recibe una lista de números.

        Debes crear una nueva lista donde cada
        número esté multiplicado por 2.

    Ejemplo:
        Si lista = [1, 2, 3]

        la función debe regresar

        [2, 4, 6]

    Pista:
        Crea una lista vacía y usa append().
    """

    # Código respuesta


    # Código respuesta

    return

# %%
ejercicio_5_23([4,7,1,2])

# %%
calificador.califica_ejercicio_pyg_23(ejercicio_5_23)

# %%
@Controlador("5", "ejercicio_pyg_28")
def ejercicio_5_24(lista: list):
    """
    Instrucciones:
        Esta función recibe una lista de números.

        Debes crear una nueva lista que contenga
        únicamente los números pares.

    Ejemplo:
        Si lista = [1, 2, 3, 4, 5, 6]

        la función debe regresar

        [2, 4, 6]
    """

    # Código respuesta

    
    # Código respuesta

    return

# %%
ejercicio_5_24([20, 30, 12,12,13])

# %%
calificador.califica_ejercicio_pyg_24(ejercicio_5_24)

# %%
@Controlador("5", "ejercicio_pyg_29")
def ejercicio_5_25(lista: list):
    """
    Instrucciones:
        Esta función recibe una lista de números.

        Debes recorrer la lista con un ciclo for
        y encontrar el número mayor.

    Ejemplo:
        Si lista = [3, 7, 2, 9, 5]

        la función debe regresar 9

    Pista:
        Puedes guardar el valor mayor
        en una variable y actualizarla
        cuando encuentres un número mayor.
        
    Advertencia:
        Si bien existe la función max de python que da el valor máximo
        de una lista, la recomendación es hacerlo usando con ciclos para que practiques
    """

    # Código respuesta


    # Código respuesta

    return

# %%
ejercicio_5_25([20,4,5,6,70,8])

# %%
calificador.califica_ejercicio_pyg_25(ejercicio_5_25)
