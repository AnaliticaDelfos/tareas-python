# %%
#
#
# EJECUTAR ESTA CELDA CADA VEZ QUE ENTRES A HACER LA TAREA
#
#

#####################################
#  Operaciones básicas
#####################################


import calificador
from controlador import Controlador

# %%
@Controlador("1", "ejercicio_pyg_1")
def ejercicio_1_1(a: int, b: int):
    """
    Instrucciones:
        Esta función toma los parámetros a y b
        y devuelve el resultado de multiplicarlos.
        Usa la función round para redondear a 2 decimales.
        

    Ejemplo:
        Si a = 3
        y b = 4
        la función debe regresar 12
        
        La función round se usa como:
        round(3.1416, 2)
        Ahí redondeamos el número 3.1416 a dos decimales

    Recuerda:
        Lo que la función "regresa" va justo después
        de la palabra return

    Recuerda:
        Cuida la indentación.
    """

    # Código respuesta

    respuesta = a * b

    # Código respuesta

    return round(respuesta, 2)

# %%
ejercicio_1_1(-10, 34.456)
# Out:
# -344.56

# %%
calificador.califica_ejercicio_pyg_1(ejercicio_1_1)
# Out:
# ...
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_pyg_1 <============
#
# ...
#
#
# ...
#             ||          Calificación: 100.0
#             ||          Aciertos: 2
#             ||          Errores: 0
# ...
#
# ======> Casos existosos: <======
#
# Valores de entrada: [10, 34.456].             Valor esperado: 344.56.             Valor obtenido: 344.56
#
# Valores de entrada: [-10, 34.456].             Valor esperado: -344.56.             Valor obtenido: -344.56
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_pyg_2")
def ejercicio_1_2(a: float, b: float):
    """
    Instrucciones:
        Esta función toma dos números y devuelve
        el promedio entre ellos.
        Usa la función round para redondear a 2 decimales.

    Ejemplo:
        Si a = 6
        y b = 8
        la función debe regresar 7

    Pista:
        El promedio de dos números es la suma
        dividida entre 2.
    """

    # Código respuesta

    respuesta = (a + b) / 2

    # Código respuesta

    return respuesta

# %%
ejercicio_1_2(0, 4.5)
# Out:
# 2.25

# %%
calificador.califica_ejercicio_pyg_2(ejercicio_1_2)
# Out:
# ...
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_pyg_2 <============
#
# ...
#
#
# ...
#             ||          Calificación: 100.0
#             ||          Aciertos: 2
#             ||          Errores: 0
# ...
#
# ======> Casos existosos: <======
#
# Valores de entrada: [3, 4.5].             Valor esperado: 3.75.             Valor obtenido: 3.75
#
# Valores de entrada: [0, 4.5].             Valor esperado: 2.25.             Valor obtenido: 2.25
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_pyg_3")
def ejercicio_1_3(nombre: str):
    """
    Instrucciones:
        Esta función recibe un nombre y devuelve
        un saludo que diga:

        "Hola, <nombre>"

    Ejemplo:
        Si nombre = "Ana"

        la función debe regresar:
        "Hola, Ana"

    Pista:
        Puedes unir textos usando el operador +
    """

    # Código respuesta

    respuesta = "Hola, " + nombre

    # Código respuesta

    return respuesta

# %%
ejercicio_1_3("Wolfeschlegelsteinhausenbergerdorff")
# Out:
# 'Hola, Wolfeschlegelsteinhausenbergerdorff'

# %%
calificador.califica_ejercicio_pyg_3(ejercicio_1_3)
# Out:
# ...
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_pyg_3 <============
#
# ...
#
#
# ...
#             ||          Calificación: 100.0
#             ||          Aciertos: 2
#             ||          Errores: 0
# ...
#
# ======> Casos existosos: <======
#
#  Valores de entrada: Pepe.              Valor esperado: Hola, Pepe.              Valor obtenido: Hola, Pepe
#
#  Valores de entrada: Wolfeschlegelsteinhausenbergerdorff.              Valor esperado: Hola, Wolfeschlegelsteinhausenbergerdorff.              Valor obtenido: Hola, Wolfeschlegelsteinhausenbergerdorff
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_pyg_4")
def ejercicio_1_4(minutos: int):
    """
    Instrucciones:
        Esta función recibe una cantidad de minutos
        y devuelve el equivalente en segundos.

    Ejemplo:
        Si minutos = 2

        la función debe regresar 120

    Pista:
        Un minuto tiene 60 segundos.
    """

    # Código respuesta

    respuesta = minutos * 60

    # Código respuesta

    return respuesta

# %%
ejercicio_1_4(8)
# Out:
# 480

# %%
calificador.califica_ejercicio_pyg_4(ejercicio_1_4)
# Out:
# ...
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_pyg_4 <============
#
# ...
#
#
# ...
#             ||          Calificación: 100.0
#             ||          Aciertos: 2
#             ||          Errores: 0
# ...
#
# ======> Casos existosos: <======
#
#  Valores de entrada: 120.              Valor esperado: 7200.              Valor obtenido: 7200
#
#  Valores de entrada: 8.              Valor esperado: 480.              Valor obtenido: 480
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============

# %%
@Controlador("1", "ejercicio_pyg_5")
def ejercicio_1_5(base: float, altura: float):
    """
    Instrucciones:
        Esta función recibe la base y la altura
        de un rectángulo y devuelve su área.
        Usa la función round para redondear a 2 decimales.

    Ejemplo:
        Si base = 5
        y altura = 3

        la función debe regresar 15

    Pista:
        El área de un rectángulo se calcula
        multiplicando base por altura.
    """

    # Código respuesta

    respuesta = base * altura

    # Código respuesta

    return round(respuesta, 2)

# %%
ejercicio_1_5(348.2, 12.09)
# Out:
# 4209.74

# %%
calificador.califica_ejercicio_pyg_5(ejercicio_1_5)
# Out:
# ...
#
# ============> Calificando: tarea 1 - ejercicio ejercicio_pyg_5 <============
#
# ...
#
#
# ...
#             ||          Calificación: 100.0
#             ||          Aciertos: 2
#             ||          Errores: 0
# ...
#
# ======> Casos existosos: <======
#
# Valores de entrada: [3, 4].             Valor esperado: 12.             Valor obtenido: 12
#
# Valores de entrada: [348.2, 12.09].             Valor esperado: 4209.74.             Valor obtenido: 4209.74
#
# ======> No hubo errores :D <======
#
# ============> Calificación recibida <============
