# %% [markdown]
# # CS106 - Sesión 1 | Notebook 05: Expediente mínimo

# %% [markdown]
# En un notebook casi en blanco, crea el "expediente mínimo" de un paciente ficticio asignando 4 variables:
# - nombre, edad, peso y estatura
# - y luego calcular su IMC usando las variables creadas.
