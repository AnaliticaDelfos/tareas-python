# %% [markdown]
# # CS106 - Sesión 2 | Notebook 10: Mini-Reto - Explorador de Cohorte 🕵️‍♂️
#
# ### Enfoque
# El objetivo de este reto es integrar todas las habilidades de **importación y diagnóstico estructural** adquiridas hoy. En la investigación real, el primer paso siempre es verificar la "salud" de la base de datos: ¿llegaron todos los pacientes?, ¿se entienden los diagnósticos?, ¿faltan datos clave?
#
# Este notebook es una evidencia crítica para tu **Portafolio de Actividades (90%)**.

# %% [markdown]
# ## Instrucciones para el alumno
#
# Sigue estos pasos para realizar el diagnóstico de la cohorte de estudio:
#
# 1. **Carga de librerías:** Activa el paquete `readr` para poder leer archivos CSV.
# 2. **Importación:** Carga el archivo `cohorte_estudio.csv` (el que creamos anteriormente) y asígnalo a una variable llamada `datos_pacientes`.
# 3. **Dimensiones:** Usa una función para reportar el número total de pacientes (filas) y variables (columnas).
# 4. **Inspección de variables:** Usa `glimpse()` o `str()` para confirmar si las variables críticas (`edad`, `sexo`, `diagnostico`) fueron leídas con el tipo de dato correcto (numérico o texto).
# 5. **Integridad de datos:** Identifica y cuenta cuántos datos faltantes (`NA`) existen en total en la base de datos.
# 6. **Conclusión:** Crea una celda de texto al final y escribe una breve nota sobre si la base de datos está "sana" o si encontraste problemas que deban reportarse.
