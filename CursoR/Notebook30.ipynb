# %% [markdown]
# # CS106 - Sesión 6 | Notebook 30: Mini-Reto - El Reporte Visual Integrador 🎨
#
# ### Enfoque
# Has aprendido la "Gramática de los Gráficos". Ahora es momento de ponerla a prueba. En este reto, actuarás como el analista principal de una nueva cohorte del IMSS. Tu misión es generar un **Reporte Ejecutivo Visual** que resuma las características principales de los 200 pacientes.
#
# Un buen gráfico vale más que mil celdas de Excel. Este notebook es una pieza clave de tu **Portafolio (90%)**.

# %% [markdown]
# ## Instrucciones para el alumno
#
# Utilizando la base `cohorte_analisis.csv`, genera **cuatro gráficos distintos** que respondan a las siguientes preguntas de investigación:
#
# 1.  **Distribución:** Crea un histograma de la `edad` con 25 bins y un color que elijas.
# 2.  **Comparación:** Crea un Boxplot que compare la `glucosa_mgdl` según el estado de `hospitalizado`. (¿Tienen más glucosa los que están en cama?).
# 3.  **Relación:** Crea un Scatter Plot (dispersión) entre `peso_kg` (X) y `glucosa_mgdl` (Y). Agrega una línea de tendencia roja.
# 4.  **Frecuencia:** Crea un gráfico de barras que muestre cuántos pacientes hay por cada `diagnostico`, usando colores diferentes para cada barra.
#
# **Nota:** Todos los gráficos deben tener títulos claros y etiquetas en los ejes (usando `labs()`).

# %%
library(tidyverse)
datos <- read_csv("cohorte_analisis.csv")

# %%
# 1. HISTOGRAMA DE EDAD
# ESCRIBE TU CÓDIGO AQUÍ:

# %%
# 2. BOXPLOT DE GLUCOSA POR HOSPITALIZACIÓN
# ESCRIBE TU CÓDIGO AQUÍ:

# %%
# 3. RELACIÓN PESO VS GLUCOSA
# ESCRIBE TU CÓDIGO AQUÍ:

# %%
# 4. FRECUENCIA DE DIAGNÓSTICOS
# ESCRIBE TU CÓDIGO AQUÍ:

# %% [markdown]
# ### 📝 Conclusión del Analista
# **Pregunta:** Basado únicamente en tus 4 gráficos, describe brevemente: ¿Cuál es el perfil general de esta cohorte? (Ej. "Es una población mayoritariamente diabética, donde los hospitalizados tienen glucosas más altas...").
#
# *(Escribe tu respuesta aquí haciendo doble clic)*

# %%
# Ejecuta para guardar tu avance
source("utilidades.r")
guardar_30(df_resultado)
