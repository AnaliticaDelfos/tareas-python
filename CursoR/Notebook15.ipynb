# %% [markdown]
# # CS106 - Sesión 3 | Notebook 15: Mini-Reto - El Subgrupo Crítico 🎯
#
# ### Enfoque
# Este reto integra los tres "verbos" fundamentales de la manipulación de datos que hemos aprendido hoy. El objetivo es que logres transformar una base de datos cruda en una lista de prioridades clínicas procesable.
#
# Como investigador, a menudo necesitarás identificar rápidamente a los pacientes que superan ciertos umbrales de riesgo. Este ejercicio es parte esencial de tu **Portafolio (90%)**.

# %% [markdown]
# ## Instrucciones para el alumno
#
# Imagina que necesitas reportar al jefe de servicio quiénes son los pacientes con sospecha de diabetes descontrolada en tu cohorte. Sigue estos pasos en una sola "receta" (usando Pipes):
#
# 1. **Carga de Datos:** Asegúrate de tener cargada la base `cohorte_estudio.csv`.
# 2. **Limpieza (select):** Selecciona únicamente las columnas `nombre`, `edad` y `glucosa_mgdl`.
# 3. **Filtro (filter):** Quédate solo con aquellos pacientes que tengan una **glucosa mayor a 126 mg/dL**.
# 4. **Jerarquización (arrange):** Ordena la lista de forma **descendente** (del valor de glucosa más alto al más bajo).
# 5. **Reporte:** Observa tu tabla final y responde la pregunta en la celda de texto de abajo.

# %%
# --- TU RECETA INTEGRADA INICIA AQUÍ ---

# %%
# Ejecuta para guardar tu avance
source("utilidades.r")
guardar_15(pacientes_de_interes)

# %% [markdown]
# ### 📝 Reporte de Hallazgos
# **Pregunta:** Según el análisis que acabas de realizar, ¿cuántos pacientes cumplen con el criterio de sospecha de diabetes (>126 mg/dL) y quién es el paciente con el valor más alto?
#
# *(Escribe tu respuesta aquí haciendo doble clic)*
