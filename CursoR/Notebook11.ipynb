# %% [markdown]
# # CS106 - Sesión 3 | Notebook 11: La "Gramática" de los Datos (dplyr) 🧬
#
# En esta sesión entraremos al mundo del **Tidyverse**, una colección de herramientas diseñadas para que el código de R sea legible, casi como leer una oración o una receta médica.
#
# ### El operador Pipe (`|>`)
# Imagina que estás en un hospital:
# 1. Tomas un **expediente**.
# 2. **Luego**, buscas la sección de laboratorio.
# 3. **Luego**, anotas el nivel de glucosa.
#
# En R, ese "**Luego**" se escribe con el símbolo **`|>`** (llamado Pipe). Permite conectar pasos de forma lógica.

# %% [markdown]
# ## 1. Activando el ecosistema
# Para usar la gramática de datos, primero debemos cargar la librería `tidyverse`. Esta librería incluye a `dplyr` (manipulación de tablas) y `readr` (lectura de datos).
#
# **Instrucción:** Ejecuta la celda de abajo.

# %%
# Cargamos el conjunto de herramientas
library(tidyverse)

# %% [markdown]
# ## 2. Mi primera "receta" de datos
# Vamos a usar la tabla `iris` que ya conocemos. Nota cómo el código se lee de arriba hacia abajo y de izquierda a derecha.
#
# **Instrucción:** Ejecuta el código y observa que el resultado es el conteo de filas.

# %%
# "Toma la tabla iris... LUEGO... cuenta sus filas"
iris |>
  nrow()

# %% [markdown]
# ## 3. Mini-Reto: Iniciando la receta 🌟
# Para tu **Portafolio (90%)**, vamos a aplicar esta lógica a nuestros datos clínicos.
#
# **Instrucciones:**
# 1. Carga la base de datos `cohorte_estudio.csv` usando `read_csv()`.
# 2. Guárdala en una variable llamada `datos`.
# 3. En una nueva línea, usa el Pipe `|>` para conectar `datos` con la función `head()`.

# %%
# 1. Carga los datos
datos <- read_csv("cohorte_estudio.csv")

# 2. Usa el pipe para ver los primeros 6 pacientes
# ESCRIBE TU CÓDIGO AQUÍ:

# %%
# Ejecuta para guardar tu avance
source("utilidades.r")
guardar_11(df_respuesta)

# %% [markdown]
# ### ✅ Logro Alcanzado:
# Has logrado encadenar tus primeras instrucciones de forma legible. ¡Ya estás listo para aprender el primer verbo de esta gramática: `select()`!
