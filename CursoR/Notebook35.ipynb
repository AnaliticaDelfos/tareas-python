# %% [markdown]
# # CS106 - Sesión 7 | Notebook 35: Mini-Reto - Generar una Tabla 1 de forma automática 🏆
#
# ### Enfoque
# Has llegado al final del bloque de automatización. Tu objetivo hoy es actuar como el investigador principal de este estudio y generar la **Tabla 1 oficial** de la cohorte.
#
# Esta tabla no solo debe ser estadísticamente exacta, sino estéticamente impecable para cumplir con los estándares de una revista científica de alto impacto.

# %% [markdown]
# ## Instrucciones para el alumno
#
# Utilizando la base `cohorte_analisis.csv`, construye una tabla descriptiva que cumpla con los siguientes requisitos en un solo bloque de código:
#
# 1.  **Selección:** Incluye las variables `edad`, `sexo`, `glucosa_mgdl`, `peso_kg` y `hospitalizado`.
# 2.  **Comparación:** Divide la tabla por la variable **`diagnostico`**.
# 3.  **Estética:** * Cambia las etiquetas a español (ej. "Nivel de Glucosa", "Peso Corporal", etc.).
#     * Asegúrate de que las etiquetas estén en **negrita**.
#     * Muestra la **Media y Desviación Estándar** para el Peso y la Estatura.
# 4.  **Estadística:** * Añade una columna de **Total** al inicio.
#     * Añade la columna de **valor p** para comparar entre diagnósticos.
#     * Resalta en negrita los valores de $p < 0.05$.
# 5.  **Encabezados:** Cambia el título de la primera columna a "**Característica Basal**".

# %%
library(tidyverse)
library(gtsummary)

# Carga de datos
datos <- read_csv("cohorte_analisis.csv")

# %%
# --- TU TABLA DE PUBLICACIÓN AUTOMÁTICA AQUÍ ---

# Tips:
# 1. Empieza con select()
# 2. Sigue con tbl_summary(by = ...)
# 3. Añade add_overall(), add_p() y bold_p()
# 4. Termina con los toques estéticos bold_labels() y modify_header()

# %% [markdown]
# ### 📝 Análisis de Resultados
# **Pregunta:** Observa tu tabla final. Basado en los valores p, ¿existe alguna variable donde las diferencias entre los grupos de diagnóstico **NO** sean significativas ($p > 0.05$)? ¿Qué interpretación clínica le das a esto?
#
# *(Escribe tu respuesta aquí haciendo doble clic)*

# %%
# Ejecuta para guardar tu avance
source("utilidades.r")
guardar_35(df_resultado)
