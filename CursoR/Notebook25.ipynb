# %% [markdown]
# # CS106 - Sesión 5 | Notebook 25: Mini-Reto - El Dataset Impecable 🏆
#
# ### Enfoque
# Este es el reto integrador de la sesión de Imputación. Tu objetivo es procesar la cohorte de 200 pacientes para que no quede ni un solo dato faltante (`NA`) en las variables clave, aplicando el criterio clínico adecuado para cada una.
#
# Un dataset impecable es la base de cualquier publicación científica de alto impacto. ¡Demuestra tus habilidades de curación de datos!

# %% [markdown]
# ## Instrucciones para el alumno
#
# Utilizando la base `cohorte_limpieza.csv`, realiza las siguientes acciones en una sola secuencia de código (Pipes):
#
# 1. **Diagnóstico inicial:** Identifica las variables con NAs.
# 2. **Imputación Numérica:** Llena los vacíos de `edad` con la **mediana** y los de `glucosa_mgdl` con el **promedio**.
# 3. **Imputación Categórica:** Llena los vacíos de `sexo` con la etiqueta **"U"** (Unknown/Desconocido) y los de `diagnostico` con **"Sin registro"**.
# 4. **Criterio de Exclusión:** Elimina (`drop_na`) a cualquier paciente que aún tenga el `peso_kg` vacío (considerando que el peso es vital para tu estudio y no quieres imputarlo).
# 5. **Verificación:** Al final, usa `miss_var_summary()` para demostrar que ya no hay NAs.

# %%
# --- ESCRIBE TU CÓDIGO AQUÍ ---

# %%
# Ejecuta para guardar tu avance
source("utilidades.r")
guardar_21(df_resultado)
