# %% [markdown]
# # CS106 - Sesión 4 | Notebook 20: Mini-Reto - Reporte de Desempeño Clínico 📊
#
# ### Enfoque
# Este reto final de la sesión consiste en transformar datos individuales en **indicadores grupales**. Como investigador, no basta con saber qué tiene cada paciente; el nivel directivo o editorial te pedirá resúmenes: "¿Cuál es el promedio de glucosa de los hospitalizados?" o "¿Cómo se distribuye el riesgo por grupo?".
#
# Este notebook es la pieza más avanzada de tu **Portafolio (90%)** hasta el momento.

# %% [markdown]
# ## Instrucciones para el alumno
#
# Imagina que debes entregar un reporte rápido sobre el estado de la cohorte. Realiza la siguiente "super receta" de datos usando Pipes (`|>`):
#
# 1. **Importación:** Carga la base `cohorte_estudio.csv`.
# 2. **Clasificación (mutate):** Crea una nueva columna llamada `condicion_glucosa`.
#    * Si la `glucosa_mgdl` es mayor o igual a 126, etiquétala como **"Alta"**.
#    * De lo contrario, etiquétala como **"Normal"**.
# 3. **Agrupamiento (group_by):** Divide la tabla según si el paciente está **`hospitalizado`**.
# 4. **Resumen (summarise):** Para cada grupo (hospitalizados vs. no hospitalizados), calcula:
#    * El total de pacientes (`n()`).
#    * El promedio de la edad.
#    * El valor máximo de glucosa encontrado.
# 5. **Reporte:** Responde a la pregunta final basándote en tu tabla de resultados.

# %%
# --- TU REPORTE INTEGRADO INICIA AQUÍ ---
